# %%
import pandas as pd

df = pd.read_csv('final_df.csv')

cols_to_drop = ['num_nights', 'avg_sleep_hours', 'mean_glucose', 'max_glucose', 
                'min_glucose', 'std_glucose', 'num_days']

# %%
corr_matrix = df[['tir', 'tar', 'cv_glucose']].corr()
print(corr_matrix)
# Out:
#                  tir       tar  cv_glucose
# tir         1.000000 -0.988333   -0.380953
# tar        -0.988333  1.000000    0.353691
# cv_glucose -0.380953  0.353691    1.000000

# %%
df.to_csv('final_df.csv', index=False)
