# %%
import pandas as pd

comp = pd.read_csv('race_results/summary.csv')

comp
# Out:
#                                          strata_race    n  n_train  n_test  \
# 0  White or Caucasian_pre_diabetes_lifestyle_cont...  218      174      44
# 1                  Black or African American_healthy  115       92      23
# 2  Asian_oral_medication_and_or_non_insulin_injec...  147      117      30
# 3                         White or Caucasian_healthy  395      316      79
# 4  White or Caucasian_oral_medication_and_or_non_...  287      229      58
# 5            Asian_pre_diabetes_lifestyle_controlled  177      141      36
# 6               White or Caucasian_insulin_dependent  102       81      21
# 7  Black or African American_oral_medication_and_...  175      140      35
# 8  Black or African American_pre_diabetes_lifesty...  113       90      23
# 9                                      Asian_healthy  200      160      40
#
#                                 enet_best_params   enet_r2  enet_r2_se  \
# ...

# %%
import pandas as pd

comp = pd.read_csv('weight_class_results/summary.csv')

comp
# Out:
#                                  strata_weight_class    n  n_train  n_test  \
# 0           Normal_pre_diabetes_lifestyle_controlled  156      124      32
# 1                                    Obesity_healthy  231      184      47
# 2  Overweight_oral_medication_and_or_non_insulin_...  210      168      42
# 3                                 Overweight_healthy  271      216      55
# 4       Overweight_pre_diabetes_lifestyle_controlled  185      148      37
# 5  Normal_oral_medication_and_or_non_insulin_inje...  131      104      27
# 6  Obesity_oral_medication_and_or_non_insulin_inj...  322      257      65
# 7                          Obesity_insulin_dependent  151      120      31
# 8                                     Normal_healthy  242      193      49
# 9          Obesity_pre_diabetes_lifestyle_controlled  203      162      41
#
#                                enet_best_params   enet_r2  enet_r2_se  \
# 0   {'enet__alpha': 0.1, 'enet__l1_ratio': 0.5}  0.660449    0.058058
# ...

# %%
import pandas as pd

comp = pd.read_csv('sex_results/summary.csv')

comp
# Out:
#                                           strata_sex    n  n_train  n_test  \
# 0           Female_pre_diabetes_lifestyle_controlled  351      280      71
# 1                                       Male_healthy  295      236      59
# 2  Male_oral_medication_and_or_non_insulin_inject...  307      245      62
# 3                             Male_insulin_dependent  122       97      25
# 4                                     Female_healthy  464      371      93
# 5             Male_pre_diabetes_lifestyle_controlled  198      158      40
# 6                           Female_insulin_dependent  124       99      25
# 7  Female_oral_medication_and_or_non_insulin_inje...  356      284      72
#
#                               enet_best_params   enet_r2  enet_r2_se  \
# 0  {'enet__alpha': 0.1, 'enet__l1_ratio': 0.9}  0.733317    0.041644
# 1  {'enet__alpha': 0.1, 'enet__l1_ratio': 0.7}  0.399333    0.352378
# 2  {'enet__alpha': 0.1, 'enet__l1_ratio': 0.3}  0.659039    0.065237
# ...
